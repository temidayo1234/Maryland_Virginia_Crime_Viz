# %%
# Dependencies
import numpy as np 
import pandas as pd
pd.set_option('display.max_rows', 30000)
import warnings
warnings.filterwarnings('ignore')
from sqlalchemy import create_engine

# %% [markdown]
# ## Lowest Crime Vs Education

# %%
#lowest crime file
dmv_crime = "dmv_crime.csv"
dmv_crime_df = pd.read_csv(dmv_crime)
dmv_crime_df["State"]=dmv_crime_df['State'].str.title()
dmv_crime_df
# Out:
#         State               City  Violent Crime Rate   Latitude  Longitude
# 0    Maryland           La Plata                0.39  38.513875 -77.010340
# 1    Maryland      Mount Rainier                0.52  38.942660 -76.967057
# 2    Maryland             Laurel                0.45  39.093136 -76.881945
# 3    Maryland        Westminster                0.32  39.564201 -76.980701
# 4    Maryland         Manchester                0.02  39.661210 -76.884980
# 5    Maryland     Landover Hills                0.55  38.943167 -76.892195
# 6    Maryland          Hampstead                0.14  39.614552 -76.864427
# 7    Maryland            Hurlock                0.24  38.643824 -75.863003
# 8    Maryland     Havre de Grace                0.25  39.560095 -76.155170
# 9    Maryland         Hagerstown                0.59  39.588870 -77.700213
# 10   Maryland     New Carrollton                0.42  38.969833 -76.879973
# 11   Maryland         Greensboro                0.32  38.968592 -75.790732
# 12   Maryland        Hyattsville                0.45  38.952860 -76.946296
# 13   Maryland         North East                0.08  39.600110 -75.941330
# 14   Maryland          Taneytown                0.16  39.657449 -77.169055
# 15   Maryland         Perryville                0.13  39.571449 -76.033281
# 16   Maryland      Pocomoke City                0.41  38.089201 -75.537185
# 17   Maryland      Princess Anne                0.84  38.200553 -75.752920
# 18   Maryland            Ridgely                0.37  38.956135 -75.889093
# 19   Maryland     Riverdale Park                0.71  38.963444 -76.931641
# 20   Maryland          Salisbury                0.94  38.382445 -75.633621
# 21   Maryland      Seat Pleasant                0.75  38.896223 -76.906640
# 22   Maryland         Smithsburg                0.03  39.654820 -77.572770
# 23   Maryland          Snow Hill                0.34  38.217824 -75.326618
# 24   Maryland       St. Michaels                0.67  38.785120 -76.224390
# 25   Maryland           Thurmont                0.14  39.610876 -77.398931
# 26   Maryland             Trappe                0.20  38.664452 -76.058006
# 27   Maryland     Upper Marlboro                0.11  38.816171 -76.786093
# 28   Maryland          Greenbelt                0.45  38.833563 -76.877743
# 29   Maryland        Ocean Pines                0.05  38.395392 -75.155742
# 30   Maryland          Glenarden                0.24  39.713941 -76.651296
# 31   Maryland             Delmar                0.59  38.452527 -75.574165
# 32   Maryland          Frostburg                0.10  39.642060 -78.912502
# 33   Maryland          Fruitland                0.19  38.320318 -75.620806
# 34   Maryland           Aberdeen                0.56  39.499909 -76.231177
# 35   Maryland          Annapolis                0.48  38.987750 -76.552800
# 36   Maryland          Baltimore                1.54  39.296536 -76.623489
# 37   Maryland            Bel Air                0.19  39.547557 -76.321984
# 38   Maryland             Berlin                0.07  38.310447 -75.320901
# 39   Maryland     Berwyn Heights                0.30  38.993999 -76.910529
# 40   Maryland        Bladensburg                0.84  38.939280 -76.933860
# 41   Maryland              Bowie                0.11  38.982612 -76.743790
# 42   Maryland          Brentwood                0.03  38.943170 -76.956640
# 43   Maryland          Brunswick                0.63  39.317945 -77.624701
# 148  Virginia        Buena Vista                0.08  37.730001 -79.355121
# 149  Virginia           Culpeper                0.16  38.511694 -77.992800
# 150  Virginia         Blackstone                0.06  37.122370 -77.978923
# 151  Virginia           Danville                0.61  36.603501 -79.376228
# 152  Virginia           Damascus                0.25  36.645463 -81.742678
# 153  Virginia           Leesburg                0.16  39.041987 -77.605404
# 154  Virginia            Lebanon                0.15  36.908553 -82.053655
# 155  Virginia      Lawrenceville                0.20  36.734246 -77.813561
# 156  Virginia               Hurt                0.08  37.092640 -79.296410
# 157  Virginia         Hillsville                0.07  36.730347 -80.675070
# 158  Virginia          Haymarket                0.10  38.721912 -77.466897
# 159  Virginia       Harrisonburg                0.22  38.422777 -78.877137
# 160  Virginia            Hampton                0.28  37.072658 -76.389920
# 161  Virginia           Grottoes                0.07  38.272465 -78.805841
# 162  Virginia             Gretna                0.08  36.983015 -79.321101
# 163  Virginia       Gordonsville                0.06  38.175906 -78.181467
# 164  Virginia          Gate City                0.10  36.621664 -82.542414
# 165  Virginia           Hopewell                0.36  37.286676 -77.296596
# 166  Virginia        Front Royal                0.20  38.928308 -78.174537
# 167  Virginia              Galax                0.30  36.660281 -80.913605
# 168  Virginia             Dublin                0.11  37.122327 -80.752614
# 169  Virginia           Dumfries                0.04  38.567620 -77.328040
# 170  Virginia             Dayton                0.13  38.414850 -78.938640
# 171  Virginia            Emporia                0.56  36.694745 -77.535517
# 172  Virginia             Exmore                0.42  37.531800 -75.822990
# 173  Virginia             Elkton                0.14  38.407900 -78.623630
# 174  Virginia       Falls Church                0.14  38.884177 -77.171752
# 175  Virginia          Farmville                0.17  37.280694 -78.421284
# 176  Virginia           Franklin                0.39  36.682635 -76.942233
# 177  Virginia     Fredericksburg                0.41  38.295135 -77.483689
# 178  Virginia       Fairfax City                0.16  38.855754 -77.313422

# %%
#lowest crime file
lowest_crime = "dmv_crime.csv"
lowest_crime_df = pd.read_csv(lowest_crime)
lowest_crime_df['State'] = lowest_crime_df['State'].str.title()
#lowest_crime_df["State"] = lowest_crime_df['State'].replace("District Of Columbia","District of Columbia")
#lowest_crime_df["City"] = lowest_crime_df['City'].replace("Santaquin/Genola","Santaquin")
#education file
education ="education.csv"
education_df=pd.read_csv(education)
#education_df["City"] = education_df['City'].replace("Wrangell city and borough","Wrangell")
#merge the two files
merge_df=pd.merge(left=lowest_crime_df, right=education_df, on=['State','City'], how='left')
merge_df=merge_df.dropna().reset_index(drop=True)
#create new columns for percentage calculation
merge_df['Nones']=''
merge_df['High_Schools']=''
merge_df['Associates'']=''
merge_df['Percent_Bachelors']=''
merge_df['Percent_Graduate']=''
#create list to hold the percent calculation from for loop
p_none=[]
p_HS=[]
p_AS=[]
p_BA=[]
p_GR=[]
#Percentage of each category
for index,row in merge_df.iterrows():
    pNone = (row['None']/row['Total'])*100
    p_none.append(round(pNone,2))
    pHS = (row['High School']/row['Total'])*100
    p_HS.append(round(pHS,2))
    pAS = (row['Associates']/row['Total'])*100
    p_AS.append(round(pAS,2))
    pBA = (row['Bachelors']/row['Total'])*100
    p_BA.append(round(pBA,2))
    pGR = (row['Graduate']/row['Total'])*100
    p_GR.append(round(pGR,2))
#Insert percent into dataframe
merge_df['Percent_None']=p_none
merge_df['Percent_High_School']=p_HS
merge_df['Percent_Associates']=p_AS
merge_df['Percent_Bachelors']=p_BA
merge_df['Percent_Graduate']=p_GR

merge_df1=merge_df.loc[:,['State','City','Percent_None','Percent_High_School','Percent_Associates','Percent_Bachelors','Percent_Graduate']]
merge_df1['Education']= merge_df1['City']+', ' + merge_df1['State']
merge_df1=merge_df1.loc[:,['Education','Percent_None','Percent_High_School','Percent_Associates','Percent_Bachelors','Percent_Graduate']]
merge_df1= merge_df1.T
merge_df1.to_csv("educationcrime.csv", index=True)
merge_df1
# Out:
#                                     0                        1    \
# Education            La Plata, Maryland  Mount Rainier, Maryland
# Percent_None                       8.27                    26.72
# Percent_High_School               23.27                    24.02
# Percent_Associates                37.42                    22.24
# Percent_Bachelors                 16.56                    16.72
# Percent_Graduate                  14.48                    10.31
#
#                                   2                      3    \
# Education            Laurel, Maryland  Westminster, Maryland
# Percent_None                    12.47                  11.31
# Percent_High_School              21.7                  30.46
# Percent_Associates              24.06                  28.48
# Percent_Bachelors               23.83                     19
# Percent_Graduate                17.94                  10.76
#
#                                       4                         5    \
# Education            Manchester, Maryland  Landover Hills, Maryland
# Percent_None                         8.26                     25.44
# Percent_High_School                 33.05                     32.34
# Percent_Associates                  33.51                     31.01
# Percent_Bachelors                    14.7                      7.65
# Percent_Graduate                    10.48                      3.57
#
#                                      6                  7    \
# Education            Hampstead, Maryland  Hurlock, Maryland
# Percent_None                        4.85              22.04
# Percent_High_School                29.73              44.63
# Percent_Associates                 32.01              25.93
# Percent_Bachelors                  22.53               3.04
# Percent_Graduate                   10.88               4.36
#
#                                           8                     9    ...  \
# Education            Havre de Grace, Maryland  Hagerstown, Maryland  ...
# Percent_None                             8.52                 17.02  ...
# Percent_High_School                     27.22                 36.32  ...
# Percent_Associates                      26.57                 30.31  ...
# Percent_Bachelors                       20.09                 10.11  ...
# Percent_Graduate                         17.6                  6.24  ...
#
#                                   169                 170               171  \
# Education            Dublin, Virginia  Dumfries, Virginia  Dayton, Virginia
# Percent_None                    17.76               24.67             11.38
# Percent_High_School             33.62               30.31             29.57
# Percent_Associates              36.47               29.98             26.59
# Percent_Bachelors                 8.3                9.66             23.62
# Percent_Graduate                 3.86                5.38              8.84
#
#                                    172               173               174  \
# Education            Emporia, Virginia  Exmore, Virginia  Elkton, Virginia
# Percent_None                     25.32             36.42             17.97
# Percent_High_School               32.6             36.06             38.29
# Percent_Associates               23.99             21.25             26.12
# Percent_Bachelors                10.48              3.36             12.73
# Percent_Graduate                  7.61              2.91              4.89
#
#                                         175                  176  \
# Education            Falls Church, Virginia  Farmville, Virginia
# Percent_None                            2.3                10.26
# Percent_High_School                    7.52                35.95
# Percent_Associates                     11.4                21.47
# Percent_Bachelors                     34.41                16.92
# Percent_Graduate                      44.36                 15.4
#
#                                     177                       178
# Education            Franklin, Virginia  Fredericksburg, Virginia
# Percent_None                      19.79                      9.02
# Percent_High_School               24.87                     26.93
# Percent_Associates                29.12                     26.71
# Percent_Bachelors                 16.12                     21.22
# Percent_Graduate                   10.1                     16.12
#
# [6 rows x 179 columns]

# %% [markdown]
# ## Lowest Crime Vs Race

# %%
#race file
race ="race.csv"
race_df=pd.read_csv(race)
#race_df["City"] = race_df['City'].replace("Wrangell city and borough","Wrangell")
#merge the two files
merge_df=pd.merge(left=lowest_crime_df, right=race_df, on=['State','City'], how='left')
merge_df=merge_df.dropna().reset_index(drop=True)
#create new columns for percentage calculation
merge_df['Blacks']=''
merge_df['American_Indian/Alaskan_Natives']=''
merge_df['Asians']=''
merge_df['Native_Hawaiian/Pacific_Islanders']=''
merge_df['Whites']=''
merge_df['Others']=''
merge_df['Two_or_Mores']=''
merge_df['Hispanic/Latinos']=''
#create list to hold the percent calculation from for loop
p_other=[]
p_HP=[]
p_AA=[]
p_W=[]
p_PI=[]
p_A=[]
p_TM=[]
p_AN=[]
#Percentage of each category
for index,row in merge_df.iterrows():
    pOther = (row['Other']/row['Total'])*100
    p_other.append(round(pOther,2))
    pHP = (row['Hispanic/Latino']/row['Total'])*100
    p_HP.append(round(pHP,2))
    pAA = (row['Black']/row['Total'])*100
    p_AA.append(round(pAA,2))
    pW = (row['White']/row['Total'])*100
    p_W.append(round(pW,2))
    pPI = (row['Native Hawaiian / Pacific Islander']/row['Total'])*100
    p_PI.append(round(pPI,2))
    pA = (row['Asian']/row['Total'])*100
    p_A.append(round(pA,2))
    pTM = (row['Two or More']/row['Total'])*100
    p_TM.append(round(pTM,2))
    pAN = (row['American Indian/Alaskan Native']/row['Total'])*100
    p_AN.append(round(pAN,2))
#Insert percent into dataframe
merge_df['Blacks']=p_AA
merge_df['American_Indian/Alaskan_Natives']=p_AN
merge_df['Asians']=p_A
merge_df['Native_Hawaiian/Pacific_Islanders']=p_PI
merge_df['Whites']=p_W
merge_df['Others']=p_other
merge_df['Two_or_Mores']=p_TM
merge_df['Hispanic/Latinos']=p_HP

merge_df2=merge_df.loc[:,['State','City','Blacks','Asians','Native_Hawaiian/Pacific_Islanders','Whites',
                          'Hispanic/Latinos','American_Indian/Alaskan_Natives','Two_or_Mores','Others']]
merge_df2['Race']= merge_df2['City']+', ' + merge_df2['State']
merge_df2=merge_df2.loc[:,['Race','Blacks','Asians','Native_Hawaiian/Pacific_Islanders','Whites',
                          'Hispanic/Latinos','American_Indian/Alaskan_Natives','Two_or_Mores','Others']]
merge_df2 = merge_df2.T
merge_df2.to_csv("racecrime.csv", index=True)
merge_df2
# Out:
#                                                   0    \
# Race                               La Plata, Maryland
# Blacks                                          26.21
# Asians                                           2.63
# Native_Hawaiian/Pacific_Islanders                   0
# Whites                                          62.49
# Hispanic/Latinos                                 3.85
# American_Indian/Alaskan_Natives                  1.03
# Two_or_Mores                                     3.48
# Others                                           0.31
#
#                                                        1                 2    \
# Race                               Mount Rainier, Maryland  Laurel, Maryland
# Blacks                                               35.92             46.17
# Asians                                                0.93              7.46
# Native_Hawaiian/Pacific_Islanders                        0                 0
# Whites                                               12.03              20.6
# Hispanic/Latinos                                     31.97             15.23
# Two_or_Mores                                   0.92               0.5
# Others                                         0.85              0.36
#
#                                                       175  \
# Race                               Falls Church, Virginia
# Blacks                                               2.03
# Asians                                              10.91
# Native_Hawaiian/Pacific_Islanders                       0
# Whites                                              69.36
# Hispanic/Latinos                                     9.29
# American_Indian/Alaskan_Natives                         0
# Two_or_Mores                                         5.02
# Others                                               3.39
#
#                                                    176                 177  \
# Race                               Farmville, Virginia  Franklin, Virginia
# Blacks                                           29.23               58.37
# Asians                                            1.17                0.59
# Native_Hawaiian/Pacific_Islanders                    0                   0
# Whites                                           63.52               38.06
# Hispanic/Latinos                                  3.42                1.04
# American_Indian/Alaskan_Natives                   0.21                   0
# Two_or_Mores                                      2.24                 1.2
# Others                                            0.21                0.74
#
#                                                         178
# Race                               Fredericksburg, Virginia
# Blacks                                                22.14
# Asians                                                 2.35
# Native_Hawaiian/Pacific_Islanders                      0.09
# Whites                                                56.82
# Hispanic/Latinos                                      10.53
# American_Indian/Alaskan_Natives                         0.2
# Two_or_Mores                                           4.38
# Others                                                 3.49
#
# [9 rows x 179 columns]

# %% [markdown]
# ## Lowest Crime Vs Marital Status

# %%
#Marital Status
marital_status ="marital_status.csv"
ms_df=pd.read_csv(marital_status)
#ms_df["City"] = ms_df['City'].replace("Wrangell city and borough","Wrangell")
#merge the two files
merge_df=pd.merge(left=lowest_crime_df, right=ms_df, on=['State','City'], how='left')
merge_df=merge_df.dropna().reset_index(drop=True)
#create new columns for percentage calculation
merge_df['Never_Marrieds']=''
merge_df['Marrieds']=''
merge_df['Divorceds']=''
merge_df['Separateds']=''
merge_df['Widoweds']=''
#create list to hold the percent calculation from for loop
p_NM=[]
p_M=[]
p_D=[]
p_S=[]
p_W=[]
#Percentage of each category
for index,row in merge_df.iterrows():
    pNM = (row['Never Married']/row['Total'])*100
    p_NM.append(round(pNM,2))
    pM = (row['Married']/row['Total'])*100
    p_M.append(round(pM,2))
    pD = (row['Divorced']/row['Total'])*100
    p_D.append(round(pD,2))
    pS = (row['Separated']/row['Total'])*100
    p_S.append(round(pS,2))
    pW = (row['Widowed']/row['Total'])*100
    p_W.append(round(pW,2))
#Insert percent into dataframe
merge_df['Never_Marrieds']=p_NM
merge_df['Marrieds']=p_M
merge_df['Divorceds']=p_D
merge_df['Separateds']=p_S
merge_df['Widoweds']=p_W

merge_df3=merge_df.loc[:,['State', 'City','Never_Marrieds','Marrieds','Divorceds',
                          'Separateds','Widoweds']]
merge_df3['Marital_Status']= merge_df3['City']+', ' + merge_df3['State']
merge_df3=merge_df3.loc[:,['Marital_Status','Never_Marrieds','Marrieds','Divorceds',
                          'Separateds','Widoweds']]
merge_df3 = merge_df3.T
merge_df3.to_csv("maritalstatuscrime.csv", index=True)
merge_df3
# Out:
#                                0                        1                 2    \
# Marital_Status  La Plata, Maryland  Mount Rainier, Maryland  Laurel, Maryland
# Never_Marrieds               34.12                    49.03             41.41
# Marrieds                     45.14                    31.92             39.54
# Divorceds                    12.74                     9.45             11.98
# Separateds                    1.14                     6.75              2.94
# Widoweds                      6.86                     2.85              4.13
#
#                                   3                     4    \
# Marital_Status  Westminster, Maryland  Manchester, Maryland
# Never_Marrieds                  38.25                 24.87
# Marrieds                        41.03                 58.77
# Divorceds                        10.4                  9.18
# Separateds                       2.84                  0.88
# Widoweds                         7.49                   6.3
#
#                                      5                    6    \
# Marital_Status  Landover Hills, Maryland  Hampstead, Maryland
# Never_Marrieds                     37.14                25.05
# Marrieds                           44.84                56.46
# Divorceds                           10.8                11.32
# Separateds                          5.23                 1.44
# Widoweds                            1.99                 5.73
#
#                               7                         8    \
# Marital_Status  Hurlock, Maryland  Havre de Grace, Maryland
# Never_Marrieds              30.16                     28.06
# Marrieds                    42.87                     51.14
# Divorceds                   18.46                     11.51
# Separateds                   1.08                       2.5
# Widoweds                     7.44                      6.79
#
#                                  9    ...               169  \
# Marital_Status  Hagerstown, Maryland  ...  Dublin, Virginia
# Never_Marrieds                 35.25  ...             31.85
# Marrieds                       39.57  ...             40.12
# Divorceds                      14.03  ...             17.61
# Separateds                      3.57  ...               5.8
# Widoweds                        7.58  ...              4.63
#
#                                170               171                172  \
# Marital_Status  Dumfries, Virginia  Dayton, Virginia  Emporia, Virginia
# Never_Marrieds               36.17             28.28              31.72
# Marrieds                     44.49             50.69              43.64
# Divorceds                    12.88             15.45              10.17
# Separateds                    4.06              0.87               3.16
# Widoweds                       2.4              4.71              11.31
#
#                              173               174                     175  \
# Marital_Status  Exmore, Virginia  Elkton, Virginia  Falls Church, Virginia
# Never_Marrieds             27.42             23.62                   30.98
# Marrieds                   34.88             48.46                   55.26
# Divorceds                  22.78             11.81                    8.56
# Separateds                  3.07              4.47                    2.57
# Widoweds                   11.85             11.64                    2.64
#
#                                 176                 177  \
# Marital_Status  Farmville, Virginia  Franklin, Virginia
# Never_Marrieds                   64               36.49
# Marrieds                      21.15               34.85
# Divorceds                      4.79               14.79
# Separateds                     3.78                 3.7
# Widoweds                       6.28               10.18
#
#                                      178
# Marital_Status  Fredericksburg, Virginia
# Never_Marrieds                      45.9
# Marrieds                           33.69
# Divorceds                          11.85
# Separateds                          3.38
# Widoweds                            5.18
#
# [6 rows x 179 columns]

# %% [markdown]
# ## Lowest Crime Vs Income

# %%
#Income
income="income.csv"
income_df=pd.read_csv(income)
income_df["City"] = income_df['City'].replace("Wrangell city and borough","Wrangell")
#merge the two files
merge_df=pd.merge(left=lowest_crime_df, right=income_df, on=['State','City'], how='left')
merge_df=merge_df.dropna().reset_index(drop=True)
merge_df['Median_Income'] = merge_df['Median Income'].copy()
merge_df4=merge_df.loc[:,['State','City', 'Median_Income']]
merge_df4['Income']= merge_df4['City']+', ' + merge_df4['State']
merge_df4=merge_df4.loc[:,['Income', 'Median_Income']]
merge_df4 = merge_df4.T
merge_df4.to_csv("incomecrime.csv", index=True)
state_avg=merge_df.loc[:,['State','City', 'Median_Income']]
state_avg = state_avg.groupby('State')
state_avg = round(state_avg['Median_Income'].mean(),2)
#state_avg.to_csv("state_average.csv", index=False)

# %% [markdown]
# ## Lowest Crime Vs Unemployment

# %%
#Unemployment Count
unemployment="unemployment.csv"
ue_df=pd.read_csv(unemployment)
ue_df["City"] = ue_df['City'].replace("Wrangell city and borough","Wrangell")
#merge the two files
merge_df=pd.merge(left=lowest_crime_df, right=ue_df, on=['State','City'], how='left')
merge_df=merge_df.dropna().reset_index(drop=True)

#create new columns for percentage calculation
merge_df['Unemployment']=''
#create list to hold the percent calculation from for loop
p_UE=[]
#Percentage of each category
for index,row in merge_df.iterrows():
    pUE = (row['Unemployment Count']/row['Population'])*100
    p_UE.append(round(pUE,2))
#Insert percent into dataframe
merge_df['Unemployment']=p_UE
merge_df6=merge_df.loc[:,['State','City','Unemployment']]
merge_df6['Unemployment_Count']= merge_df6['City']+', ' + merge_df6['State']
merge_df6=merge_df6.loc[:,['Unemployment_Count','Unemployment']]
merge_df6 = merge_df6.T
merge_df6.to_csv("unemploymentcrime.csv", index=True)
unemploy_state_avg=merge_df.loc[:,['State','City', 'Unemployment']]
unemploy_state_avg = unemploy_state_avg.groupby('State')
unemploy_state_avg = round(unemploy_state_avg['Unemployment'].mean(),2)
unemploy_state_avg.to_csv("unemployment_state_average.csv", index=True)
# Out:
# State
# Maryland    6.05
# Virginia    4.59
# Name: Unemployment, dtype: float64

# %% [markdown]
# ## Lowest Crime Vs Population

# %%
#Population
education ="education.csv"
education_df=pd.read_csv(education)
education_df["City"] = education_df['City'].replace("Wrangell city and borough","Wrangell")
#merge the two files
merge_df=pd.merge(left=lowest_crime_df, right=education_df, on=['State','City'], how='left')
merge_df=merge_df.dropna().reset_index(drop=True)
merge_df5=merge_df.loc[:,['State','City', 'Population']]
merge_df5.to_csv("totalpopulation.csv", index=False)
merge_df5
# Out:
#         State               City  Population
# 0    Maryland           La Plata      8994.0
# 1    Maryland      Mount Rainier      8329.0
# 2    Maryland             Laurel     25849.0
# 3    Maryland        Westminster     18646.0
# 4    Maryland         Manchester      4814.0
# 5    Maryland     Landover Hills      1903.0
# 6    Maryland          Hampstead      6351.0
# 7    Maryland            Hurlock      1958.0
# 8    Maryland     Havre de Grace     13445.0
# 9    Maryland         Hagerstown     40210.0
# 10   Maryland     New Carrollton     12542.0
# 11   Maryland         Greensboro      2020.0
# 12   Maryland        Hyattsville     18225.0
# 13   Maryland         North East      3700.0
# 14   Maryland          Taneytown      6740.0
# 15   Maryland         Perryville      4427.0
# 16   Maryland      Pocomoke City      4162.0
# 17   Maryland      Princess Anne      3325.0
# 18   Maryland            Ridgely      1379.0
# 19   Maryland     Riverdale Park      7169.0
# 20   Maryland          Salisbury     31883.0
# 21   Maryland      Seat Pleasant      4699.0
# 22   Maryland         Smithsburg      3010.0
# 23   Maryland          Snow Hill      2343.0
# 24   Maryland       St. Michaels      1084.0
# 25   Maryland           Thurmont      6392.0
# 26   Maryland             Trappe      1228.0
# 27   Maryland     Upper Marlboro       699.0
# 28   Maryland          Greenbelt     23827.0
# 29   Maryland        Ocean Pines     11025.0
# 30   Maryland          Glenarden      6212.0
# 31   Maryland             Delmar      3026.0
# 32   Maryland          Frostburg      8759.0
# 33   Maryland          Fruitland      5110.0
# 34   Maryland           Aberdeen     15238.0
# 35   Maryland          Annapolis     38841.0
# 115  Virginia         South Hill      4566.0
# 116  Virginia       South Boston      8037.0
# 117  Virginia         Smithfield      8233.0
# 118  Virginia         Shenandoah      2412.0
# 119  Virginia             Vienna     16341.0
# 120  Virginia              Luray      4843.0
# 121  Virginia           St. Paul      1080.0
# 122  Virginia          Lexington      7071.0
# 123  Virginia          Covington      5736.0
# 124  Virginia   Colonial Heights     17515.0
# 125  Virginia     Colonial Beach      3556.0
# 126  Virginia            Coeburn      2377.0
# 127  Virginia          Clintwood      1423.0
# 128  Virginia      Clifton Forge      3839.0
# 129  Virginia     Christiansburg     21623.0
# 130  Virginia       Chincoteague      2930.0
# 131  Virginia          Chilhowie      1839.0
# 132  Virginia         Chesapeake    230601.0
# 133  Virginia         Chase City      2312.0
# 134  Virginia    Charlottesville     45084.0
# 135  Virginia              Crewe      2746.0
# 136  Virginia       Cape Charles       912.0
# 137  Virginia          Brookneal      1184.0
# 138  Virginia            Bristol     17524.0
# 139  Virginia        Bridgewater      5844.0
# 140  Virginia          Bluefield      5350.0
# 141  Virginia      Big Stone Gap      5508.0
# 142  Virginia            Bedford      6522.0
# 143  Virginia            Ashland      7298.0
# 144  Virginia         Appalachia      1871.0
# 145  Virginia          Altavista      3464.0
# 146  Virginia         Alexandria    149315.0
# 147  Virginia           Abingdon      8143.0
# 148  Virginia             Louisa      2204.0
# 149  Virginia        Buena Vista      6666.0
# 150  Virginia           Culpeper     17167.0
# 151  Virginia         Blackstone      3553.0
# 152  Virginia           Danville     42450.0
# 153  Virginia           Damascus       759.0
# 154  Virginia           Leesburg     47872.0
# 155  Virginia            Lebanon      3388.0
# 156  Virginia      Lawrenceville      1419.0
# 157  Virginia               Hurt      1412.0
# 158  Virginia         Hillsville      2701.0
# 159  Virginia          Haymarket      1915.0
# 160  Virginia       Harrisonburg     51388.0
# 161  Virginia            Hampton    137081.0
# 162  Virginia           Grottoes      2714.0
# 163  Virginia             Gretna      1283.0
# 164  Virginia       Gordonsville      1564.0
# 165  Virginia          Gate City      2370.0
# 166  Virginia           Hopewell     22279.0
# 167  Virginia        Front Royal     14846.0
# 168  Virginia              Galax      6876.0
# 169  Virginia             Dublin      2665.0
# 170  Virginia           Dumfries      5158.0
# 171  Virginia             Dayton      1654.0
# 172  Virginia            Emporia      5672.0
# 173  Virginia             Exmore      1510.0
# 174  Virginia             Elkton      2779.0
# 175  Virginia       Falls Church     13308.0
# 176  Virginia          Farmville      8355.0
# 177  Virginia           Franklin      8457.0
# 178  Virginia     Fredericksburg     27395.0

# %%
rds_connection_string = "postgres:<password_here>@localhost:5432/md_va_crime_demo_db"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
engine.table_names()
# Out:
# []

# %%
merge_df2.to_sql(name='crime_race', con=engine, if_exists='replace', index=False)

# %%
merge_df1.to_sql(name='crime_education', con=engine, if_exists='replace', index=False)

# %%
merge_df4.to_sql(name='crime_income', con=engine, if_exists='replace', index=False)

# %%
merge_df6.to_sql(name='crime_unemployment', con=engine, if_exists='replace', index=False)

# %%
merge_df5.to_sql(name='crime_population', con=engine, if_exists='replace', index=False)

# %%
merge_df3.to_sql(name='crime_maritalstatus', con=engine, if_exists='replace', index=False)
